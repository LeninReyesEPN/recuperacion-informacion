# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import gensim.downloader as api

model = api.load("word2vec-google-news-300")

model
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/numpy/_core/numerictypes.py:325, in issubclass_(arg1, arg2)
#     324 try:
# --> 325     return issubclass(arg1, arg2)
#     326 except TypeError:
#
# TypeError: issubclass() arg 1 must be a class
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 import gensim.downloader as api
# ----> 3 model = api.load("word2vec-google-news-300")
#       5 model
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/downloader.py:503, in load(name, return_path)
#     501 sys.path.insert(0, BASE_DIR)
#     502 module = __import__(name)
# --> 503 return module.load_data()
#
# File ~/gensim-data/word2vec-google-news-300/__init__.py:8, in load_data()
#       6 def load_data():
#       7     path = os.path.join(base_dir, 'word2vec-google-news-300', "word2vec-google-news-300.gz")
# ----> 8     model = KeyedVectors.load_word2vec_format(path, binary=True)
#       9     return model
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/models/keyedvectors.py:1721, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1674 @classmethod
#    1675 def load_word2vec_format(
#    1676         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1677         limit=None, datatype=REAL, no_header=False,
#    1678     ):
#    1679     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1680
#    1681     Warnings
#    (...)
#    1719
#    1720     """
# -> 1721     return _load_word2vec_format(
#    1722         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1723         limit=limit, datatype=datatype, no_header=no_header,
#    1724     )
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/models/keyedvectors.py:2067, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2064 kv = cls(vector_size, vocab_size, dtype=datatype)
#    2066 if binary:
# -> 2067     _word2vec_read_binary(
#    2068         fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding
#    2069     )
#    2070 else:
#    2071     _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/models/keyedvectors.py:1962, in _word2vec_read_binary(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding)
#    1960 new_chunk = fin.read(binary_chunk_size)
#    1961 chunk += new_chunk
# -> 1962 processed_words, chunk = _add_bytes_to_kv(
#    1963     kv, counts, chunk, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    1964 tot_processed_words += processed_words
#    1965 if len(new_chunk) < binary_chunk_size:
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/models/keyedvectors.py:1945, in _add_bytes_to_kv(kv, counts, chunk, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    1943 word = word.lstrip('\n')
#    1944 vector = frombuffer(chunk, offset=i_vector, count=vector_size, dtype=REAL).astype(datatype)
# -> 1945 _add_word_to_kv(kv, counts, word, vector, vocab_size)
#    1946 start = i_vector + bytes_per_vector
#    1947 processed_words += 1
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/models/keyedvectors.py:1925, in _add_word_to_kv(kv, counts, word, weights, vocab_size)
#    1923     logger.warning("vocabulary file is incomplete: '%s' is missing", word)
#    1924     word_count = None
# -> 1925 kv.set_vecattr(word, 'count', word_count)
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/models/keyedvectors.py:353, in KeyedVectors.set_vecattr(self, key, attr, val)
#     334 def set_vecattr(self, key, attr, val):
#     335     """Set attribute associated with the given key to value.
#     336
#     337     Parameters
#    (...)
#     351
#     352     """
# --> 353     self.allocate_vecattrs(attrs=[attr], types=[type(val)])
#     354     index = self.get_index(key)
#     355     self.expandos[attr][index] = val
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/gensim/models/keyedvectors.py:323, in KeyedVectors.allocate_vecattrs(self, attrs, types)
#     321     continue
#     322 prev_expando = self.expandos[attr]
# --> 323 if not np.issubdtype(t, prev_expando.dtype):
#     324     raise TypeError(
#     325         f"Can't allocate type {t} for attribute {attr}, "
#     326         f"conflicts with its existing type {prev_expando.dtype}"
#     327     )
#     328 if len(prev_expando) == target_size:
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/numpy/_core/numerictypes.py:530, in issubdtype(arg1, arg2)
#     528 if not issubclass_(arg1, generic):
#     529     arg1 = dtype(arg1).type
# --> 530 if not issubclass_(arg2, generic):
#     531     arg2 = dtype(arg2).type
#     533 return issubclass(arg1, arg2)
#
# File ~/Documents/EPN/Recuperacion de Información/recuperacion-informacion/.venv/lib/python3.9/site-packages/numpy/_core/numerictypes.py:325, in issubclass_(arg1, arg2)
#     290 """
#     291 Determine if a class is a subclass of a second class.
#     292
#    (...)
#     322
#     323 """
#     324 try:
# --> 325     return issubclass(arg1, arg2)
#     326 except TypeError:
#     327     return False
#
# KeyboardInterrupt:

# %%
vec = lambda word: model[word]

vec("word")
# Out:
# array([ 3.59375000e-01,  4.15039062e-02,  9.03320312e-02,  5.46875000e-02,
#        -1.47460938e-01,  4.76074219e-02, -8.49609375e-02, -2.04101562e-01,
#         3.10546875e-01, -1.05590820e-02, -6.15234375e-02, -1.55273438e-01,
#        -1.52343750e-01,  8.54492188e-02, -2.70996094e-02,  3.84765625e-01,
#         4.78515625e-02,  2.58789062e-02,  4.49218750e-02, -2.79296875e-01,
#         9.09423828e-03,  4.08203125e-01,  2.40234375e-01, -3.06640625e-01,
#        -1.80664062e-01,  4.73632812e-02, -2.63671875e-01,  9.08203125e-02,
#         1.37695312e-01, -7.20977783e-04,  2.67333984e-02,  1.92382812e-01,
#        -2.29492188e-02,  9.70458984e-03, -7.37304688e-02,  4.29687500e-01,
#        -7.93457031e-03,  1.06445312e-01,  2.80761719e-02, -2.29492188e-01,
#        -1.91650391e-02, -2.36816406e-02,  3.51562500e-02,  1.71875000e-01,
#        -1.12304688e-01,  6.25000000e-02, -1.69921875e-01,  1.29882812e-01,
#        -1.54296875e-01,  1.58203125e-01, -7.76367188e-02,  1.78710938e-01,
#        -2.05078125e-01, -7.56835938e-02, -1.04492188e-01,  6.25000000e-02,
#        -2.02148438e-01, -1.09375000e-01, -8.05664062e-02,  5.49316406e-02,
#        -8.88671875e-02,  5.24902344e-02, -2.23632812e-01,  5.17578125e-02,
#        -1.83593750e-01, -6.73828125e-02, -9.13085938e-02,  1.29882812e-01,
#        -2.31933594e-02, -1.04003906e-01,  1.79687500e-01,  8.34960938e-02,
#        -8.78906250e-02, -2.17773438e-01, -6.34765625e-02,  1.33789062e-01,
#         1.62109375e-01,  2.87109375e-01, -1.14257812e-01,  6.05468750e-02,
#         1.49414062e-01, -3.08227539e-03,  1.96289062e-01, -8.98437500e-02,
#         1.45507812e-01,  1.02539062e-02,  1.22070312e-02,  3.20312500e-01,
#         1.24511719e-01,  1.20849609e-02, -1.78710938e-01,  3.71093750e-02,
#         6.98242188e-02,  1.62109375e-01,  9.86328125e-02, -2.61718750e-01,
#         1.89453125e-01, -2.83203125e-02,  4.06250000e-01,  3.56445312e-02,
#         3.10058594e-02,  2.27050781e-02,  1.30859375e-01, -1.05957031e-01,
#         8.69140625e-02, -9.76562500e-02,  1.89453125e-01,  3.17382812e-02,
#         1.10351562e-01,  2.11914062e-01, -1.66992188e-01,  1.45263672e-02,
#         1.15234375e-01,  1.59179688e-01,  9.91210938e-02, -2.40234375e-01,
#        -2.34375000e-01,  1.74804688e-01,  1.20605469e-01, -3.67187500e-01,
#        -7.81250000e-02,  1.10839844e-01, -3.35937500e-01, -9.81445312e-02,
#        -7.47070312e-02, -1.89453125e-01,  7.81250000e-02, -2.53906250e-01,
#        -6.03027344e-02, -2.46093750e-01, -9.37500000e-02,  8.64257812e-02,
#         1.15722656e-01, -1.24511719e-01,  1.61132812e-01, -6.03027344e-02,
#        -2.47070312e-01, -9.52148438e-02, -4.05273438e-02,  2.51953125e-01,
#        -1.95312500e-01, -1.31835938e-01,  6.88476562e-02,  2.67333984e-02,
#         1.03027344e-01,  1.05957031e-01, -3.01513672e-02,  3.04687500e-01,
#        -8.74023438e-02,  1.19140625e-01, -1.74560547e-02,  8.78906250e-03,
#        -1.38671875e-01, -2.85156250e-01,  2.29492188e-01, -3.55468750e-01,
#         9.52148438e-03, -4.07714844e-02, -8.88671875e-02, -1.39160156e-02],
#       dtype=float32)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity([vec("dog")], [vec("world")])
# Out:
# array([[0.03298484]], dtype=float32)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
vman = pca.fit_transform(vec_man)
vwoman = pca.fit_transform(vec_woman)
vking = pca.fit_transform(vec_king)
vqueen = pca.fit_transform(vec_queen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 vman = pca.fit_transform(vec_man)
#       2 vwoman = pca.fit_transform(vec_woman)
#       3 vking = pca.fit_transform(vec_king)
#
# NameError: name 'vec_man' is not defined

# %%
p = ['madrid','spain','paris','france']
v300 = [vec(word) for word in p]

(vec('spain') - vec('madird')) + vec('paris')

plt.figure(figsize=(10,7))
plt.annotate('madrid',)
# Out:
# 300
